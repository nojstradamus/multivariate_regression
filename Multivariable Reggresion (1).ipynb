# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_excel('Crime.xls')

# %%
df = df.drop(range(0,4))

# %%
df.columns = ['City', 'Population', 'Violent Crime', 'Murder and nonnegligent manslaughter',
             'Rape (revised definition)', 'Rape (legacy definition)', 'Robbery', 'Aggravated assault',
             'Property Crime', 'Burglary', 'Larceny theft', 'Motor vehicle theft', 'Arson']

# %%
df = df.drop(4)

# %%
df = df.drop(range(352, 355))

# %%
df = df.drop('Rape (revised definition)',axis=1)

# %%
prop_crime = df[['City', 'Population', 'Murder and nonnegligent manslaughter', 'Robbery', 'Property Crime']]

# %%
prop_crime.columns = ['City', 'Pop', 'Murder', 'Robbery', 'Property Crime']

# %%
prop_crime['Pop sqr'] = prop_crime['Pop']**2
# Out:
# c:\users\gebruiker\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
prop_crime.head()
# Out:
#                        City    Pop Murder Robbery Property Crime     Pop sqr
# 5  Addison Town and Village   2577      0       0             24     6640929
# 6             Akron Village   2846      0       0             16     8099716
# 7                    Albany  97956      8     227           4090  9595377936
# 8            Albion Village   6388      0       4            223    40806544
# 9            Alfred Village   4089      0       3             46    16719921

# %%
prop_crime.describe()
# Out:
#              City   Pop  Murder  Robbery  Property Crime   Pop sqr
# count         347   347     347      347             347       347
# unique        347   346      14       51             239       346
# top     Peekskill  9517       0        0               0  90573289
# freq            1     2     298      138               6         2

# %%
prop_crime['Murder'].mean()
# Out:
# 1.5706051873198847

# %%
prop_crime['Robbery'].mean()
# Out:
# 73.11239193083574

# %%
prop_crime[prop_crime['Murder']> 0]
# Out:
#                          City      Pop Murder Robbery Property Crime  \
# 7                      Albany    97956      8     227           4090
# 11               Amherst Town   118296      1      31           2118
# 18                     Auburn    27270      1      22            859
# 26                 Binghamton    46304      3     101           2349
# 35              Brighton Town    36689      1      10            793
# 36          Brockport Village     8284      1       5            165
# 39                    Buffalo   258789     47    1322          12491
# 88         East Fishkill Town    29315      1       1            165
# 92     East Rochester Village     6596      1       3            125
# 103            Fallsburg Town    12109      1       0            162
# 119                    Geneva    13194      1       5            343
# 131           Greenburgh Town    44787      1      16            578
# 138              Hamburg Town    45535      1      12           1167
# ...

# %%
prop_crime['Murder_cat'] = prop_crime['Murder'].apply(lambda x: 0 if x == 0 else 1)
# Out:
# c:\users\gebruiker\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
prop_crime['Robbery_cat'] = prop_crime['Robbery'].apply(lambda x: 0 if x == 0 else 1)
# Out:
# c:\users\gebruiker\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
prop_crime.head()
# Out:
#                        City    Pop Murder Robbery Property Crime     Pop sqr  \
# 5  Addison Town and Village   2577      0       0             24     6640929
# 6             Akron Village   2846      0       0             16     8099716
# 7                    Albany  97956      8     227           4090  9595377936
# 8            Albion Village   6388      0       4            223    40806544
# 9            Alfred Village   4089      0       3             46    16719921
#
#    Murder_cat  Robbery_cat
# 5           0            0
# 6           0            0
# 7           1            1
# 8           0            1
# 9           0            1
